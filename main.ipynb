# %%
from pyspark.sql import SparkSession

# %%
import os

# %%
spark = SparkSession.builder.appName("spark-session").getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 25/06/03 23:22:17 WARN Utils: Your hostname, DESKTOP-1Q8536K, resolves to a loopback address: 127.0.1.1; using 10.255.255.254 instead (on interface lo)
# 25/06/03 23:22:17 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/06/03 23:22:30 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
df = spark.read.csv("MOCK_DATA.csv", header=True, inferSchema=True)

# %%
df.show(5)
# Out:
# +---+-----------+---------+-------------------+------+--------------+------------------+---+
# | id| first_name|last_name|              email|gender|    ip_address|        Department|Age|
# +---+-----------+---------+-------------------+------+--------------+------------------+---+
# |  1|     Boothe|   Camber|  bcamber0@phoca.cz|  Male|  60.181.57.13|        Accounting| 24|
# |  2|       Joel|  Dighton| jdighton1@ucla.edu|  Male|120.35.209.193|        Accounting| 55|
# |  3|    Padraig|    Heugh|    pheugh2@wsj.com|  Male| 251.165.210.0|   Human Resources| 46|
# |  4|     Vasily|    Swait| vswait3@senate.gov|  Male|124.225.211.45|Product Management| 47|
# |  5|Worthington|    Nimmo|wnimmo4@state.tx.us|  Male|199.103.126.27|           Support| 39|
# +---+-----------+---------+-------------------+------+--------------+------------------+---+
# only showing top 5 rows

# %%
df.count()
# Out:
# 1000

# %%
df.select('email').distinct().count()
# Out:
# 1000

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
df.groupBy('Department').agg(countDistinct('email').alias('country_count')).show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df.groupBy('Department').agg(countDistinct('email').alias('country_count')).show()
#
# NameError: name 'countDistinct' is not defined

# %%
df.columns
# Out:
# ['id',
#  'first_name',
#  'last_name',
#  'email',
#  'gender',
#  'ip_address',
#  'Department',
#  'Age']

# %%
df.printSchema()
# Out:
# root
#  |-- id: integer (nullable = true)
#  |-- first_name: string (nullable = true)
#  |-- last_name: string (nullable = true)
#  |-- email: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- ip_address: string (nullable = true)
#  |-- Department: string (nullable = true)
#  |-- Age: integer (nullable = true)

# %%
df.select("id", "first_name").describe().show()
# Out:
# [Stage 12:>                                                         (0 + 1) / 1]
# +-------+-----------------+----------+
# |summary|               id|first_name|
# +-------+-----------------+----------+
# |  count|             1000|      1000|
# |   mean|            500.5|      NULL|
# | stddev|288.8194360957494|      NULL|
# |    min|                1|     Aaren|
# |    max|             1000|   Zebedee|
# +-------+-----------------+----------+
