# %% [markdown]
# ### Python Collection dataypes
# Sequence Types:	list, tuple, range
# Mapping Type:	dict

# %% [markdown]
# Dictionaries - store data values in key:value pairs

# %%
user_data_LIZ = {
    "name": "wahu",
    "age": 22,
    "country": "Kenya",
    "height": 1.4,
    "school": "lux",
    "is_available": True

}

# %%
user_data_LIZ
# Out:
# {'name': 'wahu',
#  'age': 22,
#  'country': 'Kenya',
#  'height': 1.4,
#  'school': 'lux',
#  'is_available': True}

# %%
user_data_LIZ["is_available"]
# Out:
# True

# %%
user_data_LIZ["profession"] = "data engineer"

# %%
user_data_LIZ
# Out:
# {'name': 'wahu',
#  'age': 22,
#  'country': 'Kenya',
#  'height': 1.4,
#  'school': 'lux',
#  'is_available': True,
#  'profession': 'data engineer'}

# %%
user_data_LIZ.pop("age")
# Out:
# 22

# %%
user_data_LIZ
# Out:
# {'name': 'wahu',
#  'country': 'Kenya',
#  'height': 1.4,
#  'school': 'lux',
#  'is_available': True,
#  'profession': 'data engineer'}

# %%
student  = ("Amina", 22, "Data Analytics", "Nairobi")

student_dictonary = {
    "name" : "Amina",
    "age" :  22,
    "course" : "Data Analytics",
    "county"   : "Nairobi"               
}
student_dictonary
# Out:
# {'name': 'Amina', 'age': 22, 'course': 'Data Analytics', 'county': 'Nairobi'}

# %% [markdown]
# ### Set
# A set is a collection which is unordered, unchangeable*, and unindexed.
#
# Sets are written with curly brackets.

# %%
thisset = {"apple", "banana", "cherry", "apple"}
thisset
# Out:
# {'apple', 'banana', 'cherry'}

# %%
my_list = ['nakuru', 'nairobi', 'kisumu', 'mombasa', 'nakuru', 'kisumu']
my_set = set(my_list)
my_set
# Out:
# {'kisumu', 'mombasa', 'nairobi', 'nakuru'}

# %%
for  x in my_set:
    print(x)
# Out:
# mombasa
# nairobi
# kisumu
# nakuru

# %%
ratings_01 = [5, 4, 3, 5, 2, 4, 1, 5]
avg_rating = sum(ratings_01) / len(ratings_01)
avg_rating
# Out:
# 3.625

# %% [markdown]
# ### Tuples
# Tuples are used to store multiple items in a single variable.
# A tuple is a collection which is ordered and unchangeable.
#
# Tuples are written with round brackets.

# %%
my_tuple = ('apple', 'cherry', 'banana')
my_tuple
# Out:
# ('apple', 'cherry', 'banana')

# %%
mytuple = ("Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday")

# %%
mytuple[-3]
# Out:
# 'Friday'

# %%
days_01 = ("Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday")

# %%
days_01[2:5]
# Out:
# ('Wednesday', 'Thursday', 'Friday')

# %%
my_list_tuple = list(mytuple)
my_list_tuple[0] = 'Super Monday'
my_list_tuple
# Out:
# ['Super Monday',
#  'Tuesday',
#  'Wednesday',
#  'Thursday',
#  'Friday',
#  'Saturday',
#  'Sunday']

# %%
mytuple = tuple(my_list_tuple)
mytuple
# Out:
# ('Super Monday',
#  'Tuesday',
#  'Wednesday',
#  'Thursday',
#  'Friday',
#  'Saturday',
#  'Sunday')

# %%
add_tuple = mytuple + days_01
add_tuple
# Out:
# ('Super Monday',
#  'Tuesday',
#  'Wednesday',
#  'Thursday',
#  'Friday',
#  'Saturday',
#  'Sunday',
#  'Monday',
#  'Tuesday',
#  'Wednesday',
#  'Thursday',
#  'Friday',
#  'Saturday',
#  'Sunday')

# %% [markdown]
# ### Working with Data in Python
