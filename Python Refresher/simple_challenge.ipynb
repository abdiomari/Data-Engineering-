# %% [markdown]
# Part A: print() and Strings.
#
# Q1. Write a program that prints your name, your town, and your favourite food — each on its own line.
# Q2. Print the phrase "Python is fun!" exactly 3 times using 3 separate print() statements.
# Q3. Use sep= to print "Nairobi", "Mombasa", "Kisumu" all on one line separated by " → ".
# Q4. Use print() to display this exactly:  Name: Amina | Age: 25 | City: Nairobi.
#
# Part B: Variables.
#
# Q5. Create variables for: your name, your age, the name of your city, and today's date as a string. Print all of them.
# Q6. A student scored 78 in Maths and 85 in English. Store these in variables. Print both scores and their sum.
# Q7. Start with  items = 10. Add 3 more items, then remove 5. Print the final number of items.  (Hint: update the variable each time).
# Q8. Use multiple assignment: set  length, width, height = 5, 3, 2  in one line. Print all three.

# %%
#Q1

print("Abdi Omari \nShawarma \nNakuru ")
# Out:
# Abdi Omari
# Shawarma
# Nakuru

# %%
print("Python is fun!")
print("Python is fun!")
print("Python is fun!")
# Out:
# Python is fun!
# Python is fun!
# Python is fun!

# %%
print("Name: Amina | Age: 25 | City: Nairobi")
# Out:
# Name: Amina | Age: 25 | City: Nairobi

# %%
your_name = "Abdi Omari"
your_age = 24
city = 'Nakuru'
date = '2026/05/11'

print(f"{your_name, your_age, city, date}")
# Out:
# ('Abdi Omari', 24, 'Nakuru', '2026/05/11')

# %%
maths= 78
english = 85

print(maths)
print(english)
print(maths + english )
# Out:
# 78
# 85
# 163

# %%
items = 10
print(items)
items += 3
print(items)
items -= 5
print(items)
# Out:
# 10
# 13
# 8

# %%
length, width, height = (5,3,2)
print(length)
print(width)
print(height)
# Out:
# 5
# 3
# 2
